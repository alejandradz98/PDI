# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandradz98/PDI/blob/master/PDI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ***Ejemplo PDI***

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %% [markdown]
# **ERROR DE COLAB, SOLUCION CODIGO SIGUIENTE**

# %%
image= cv2.imread('/content/drive/My Drive/ejemplo PDI/paris.jpg')
cv2.imshow("image", image)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-6-29d2ec439ae0> in <module>()
#       1 image= cv2.imread('/content/drive/My Drive/ejemplo PDI/paris.jpg')
# ----> 2 cv2.imshow("image", image)
#       3 cv2.waitKey(0)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %% [markdown]
# **SOLUCION ERROR ARRIBA SOLO PARA COLAB**

# %%
from google.colab.patches import cv2_imshow
image= cv2.imread('/content/drive/My Drive/ejemplo PDI/paris.jpg',cv2.IMREAD_UNCHANGED)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x309 at 0x7FCFF9EA6908>

# %% [markdown]
# **OPCION 1- PARA COLAB**

# %%
# !pwd
# !ls
# %cd /content/drive/My Drive/ejemplo PDI/
# !pwd
from google.colab.patches import cv2_imshow
image= cv2.imread('/content/drive/My Drive/ejemplo PDI/paris.jpg',cv2.IMREAD_UNCHANGED)
image=cv2.resize(image,(int(500),int(300)))
cv2_imshow(image)
# Out:
# /content/drive/My Drive/ejemplo PDI
# paris.jpg
# /content/drive/My Drive/ejemplo PDI
# /content/drive/My Drive/ejemplo PDI
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7FCFF5405B00>

# %% [markdown]
# **CODIGO PARA PYTHON PURO**

# %%
import os
path='/content/drive/My Drive/ejemplo PDI/'
os.chdir(path)
# !pwd
image=cv2.resize(image,(int(500),int(300)))
cv2_imshow(image)
# Out:
# /content/drive/My Drive/ejemplo PDI
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7FCFF543A9E8>

# %% [markdown]
# **CARGAR IMAGEN ORIGINAL Y VISUALIZAR CON MATPLOTLIB**

# %%
#leer una imagen
# principle of least astonichment (surprice)
img_BGR=cv2.imread('/content/drive/My Drive/ejemplo PDI/paris.jpg',cv2.IMREAD_COLOR)

plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.show()

# %% [markdown]
# **CAMBIAR DE TAMAÑO LA IMAGEN**

# %%
#Expandir
print(image.shape)
res= cv2.resize(image, None,fx=10, fy=10, interpolation =cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (300, 500, 3)
# (3000, 5000, 3)

# %%
#contraer
print(image.shape)
res= cv2.resize(image, None,fx=.1, fy=.1, interpolation =cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (300, 500, 3)
# (30, 50, 3)

# %%
plt.figure(figsize=(7,7))
plt.imshow(img_BGR)

plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# **CAMBIAR DE BGR A RGB**

# %%
img_RGB=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(img_RGB)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
img_GRAY=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,10))
plt.imshow(img_GRAY)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(img_GRAY,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()
