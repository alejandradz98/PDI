# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandradz98/PDI/blob/master/Ejerciciocafe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

import os
path='/content/drive/My Drive/PDI/'
os.chdir(path)

# %%
def displayGray3(a,b,c,title1 = "Original", title2="Edited", title3="Edited"):
  plt.figure(figsize=(3,3))
  plt.subplot(131), plt.imshow(a,cmap='gray'), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(b,cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(133), plt.imshow(c,cmap='gray'), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def display2(a,b,title1 = "Original", title2="Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(121), plt.imshow(a,cmap='gray'), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(b,cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def displayColor3(a,b,c,title1 = "Original", title2="Edited", title3="Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(131), plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(b), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(133), plt.imshow(c), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def displayColor2(a,b,title1 = "Original", title2="Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(121), plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(b), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
  
def display4(a,b,c,d, title1 = 'Original', title2= 'Editado', title3= 'Editado', title4= 'Editado'):
    plt.figure(figsize=(10,10))
    plt.subplot(221), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(222), plt.imshow(b,cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(223), plt.imshow(c, cmap='gray'), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(224), plt.imshow(d,cmap='gray'), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
img=cv2.imread('se_cafe3.jpg',cv2.IMREAD_COLOR)


image_RGB=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
r,g,b = cv2.split(image_RGB)

display4(image_RGB,r,g,b,"RGB","r","g","b")

image_LAB=cv2.cvtColor(img, cv2.COLOR_BGR2LAB);
L,A,B = cv2.split(image_LAB)
display4(image_LAB,L,A,B,"LAB","L","A","B")

image_HSV=cv2.cvtColor(img, cv2.COLOR_BGR2HSV);
H,S,V= cv2.split(image_HSV)
display4(image_HSV,H,S,V,"HSV","H","S","V")

# %%
#image_LAB=cv2.cvtColor(img, cv2.COLOR_BGR2LAB);
#L,A,B= cv2.split(image_LAB)
#display2(image_LAB,A,"LAB","A")
def binarizacion(img,minr=10,maxr=60):
    row, column = img.shape
    img1 = np.zeros((row,column),dtype = 'uint8')

    min_range = minr
    max_range = maxr

    for i in range(row):
        for j in range(column):
            if img[i,j]>min_range and img[i,j]<max_range:
                img1[i,j] = 255
            else:
                img1[i,j] = 0

    displayGray2(img,img1)

binarizacion(A,160,255)

# %%
def Threshold(img,thres):

    rows, columns = img.shape
    img2 = np.zeros( (rows, columns), dtype = np.uint8)
     
    #intervalos
    T = thres
 
    for x in range(0,rows):
        for y in range(0,columns):
            r = img[x][y]
            if T<=r:
                img2[x][y] = 255
            else:
                img2[x][y] = 0
    displayGray2(img,img2)
    return
  
Threshold(g,190)

# %%
img=cv2.imread('se_cafe1.jpg',cv2.IMREAD_COLOR)


image_RGB=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
r,g,b = cv2.split(image_RGB)

display4(image_RGB,r,g,b,"RGB","r","g","b")

image_LAB=cv2.cvtColor(img, cv2.COLOR_BGR2LAB);
L,A,B = cv2.split(image_LAB)
display4(image_LAB,L,A,B,"LAB","L","A","B")

image_HSV=cv2.cvtColor(img, cv2.COLOR_BGR2HSV);
H,S,V= cv2.split(image_HSV)
display4(image_HSV,H,S,V,"HSV","H","S","V")

# %%
def binarizacion(img,minr=10,maxr=60):
    row, column = img.shape
    img1 = np.zeros((row,column),dtype = 'uint8')

    min_range = minr
    max_range = maxr

    for i in range(row):
        for j in range(column):
            if img[i,j]>min_range and img[i,j]<max_range:
                img1[i,j] = 255
            else:
                img1[i,j] = 0

    displayGray2(img,img1)

binarizacion(A,160,255)

# %%
def Threshold(img,thres):

    rows, columns = img.shape
    img2 = np.zeros( (rows, columns), dtype = np.uint8)
     
    #intervalos
    T = thres
 
    for x in range(0,rows):
        for y in range(0,columns):
            r = img[x][y]
            if T<=r:
                img2[x][y] = 255
            else:
                img2[x][y] = 0
    displayGray2(img,img2)
    return
  
Threshold(g,190)
