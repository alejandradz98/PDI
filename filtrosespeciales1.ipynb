# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandradz98/PDI/blob/master/filtrosespeciales1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

path='/content/drive/My Drive/PDI/'
os.chdir(path)

# %%
def displayGray4(a,b,c,d, title1 = "Original", title2="Edited", title3="Edited"):
  plt.figure(figsize=(20,20))
  plt.subplot(141), plt.imshow(a,cmap='gray'), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(142), plt.imshow(b,cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(143), plt.imshow(c,cmap='gray'), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.subplot(144), plt.imshow(d,cmap='gray'), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()
  

def displayGray3(a,b,c,title1 = "Original", title2="Edited", title3="Edited"):
  plt.figure(figsize=(15,15))
  plt.subplot(131), plt.imshow(a,cmap='gray'), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(b,cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(133), plt.imshow(c,cmap='gray'), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def displayGray2(a,b,title1 = "Original", title2="Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(121), plt.imshow(a,cmap='gray'), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(b,cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def displayColor3(a,b,c,title1 = "Original", title2="Edited", title3="Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(131), plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(b), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(133), plt.imshow(c), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def displayColor2(a,b,title1 = "Original", title2="Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(121), plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(b), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def readRGB(imgPath):
  img=cv2.imread(imgPath)
  img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  return img

# %%
img=cv2.imread('nube.jpg',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))

displayGray2(img,magnitude_spectrum,"input image","magnitude spectrum")

# %%
img=cv2.imread('618.jpg',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))

displayGray2(img,magnitude_spectrum,"input image","magnitude spectrum")

# %%
img=cv2.imread('imagen4.jpg',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

# %%
img=cv2.imread('azul.jpg',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

# %%
img=cv2.imread('cuadra1.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %%
img=cv2.imread('cuadra2.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %%
img=cv2.imread('cudragir.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %%
img=cv2.imread('trian1.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

# %%
img=cv2.imread('cir1.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

# %%
img=cv2.imread('cir2.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

# %%
img=cv2.imread('trivo.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

# %%
img=cv2.imread('AAA1.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

# %%
img=cv2.imread('AAA2.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

img=cv2.imread('BBB1.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

img=cv2.imread('BBB2.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

img=cv2.imread('WWW1.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

img=cv2.imread('WWW2.png',0)
f= np.fft.fft2(img)
fshift=np.fft.fftshift(f)
magnitude_spectrum=20*np.log(np.abs(fshift))
magnitude_spectrum_m=20*np.log(np.abs(f))

displayGray3(img,magnitude_spectrum,magnitude_spectrum_m,"input image","magnitude spectrum",",agnitud spectrum2")

# %% [markdown]
# **FILTRO PASA BAJOS**

# %%
img=cv2.imread('pastel.png',0)
img_flotante= np.float32(img)
dft= cv2.dft(img_flotante,flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils,cols=img.shape
centfils,centcols= fils/2, cols/2


#creamos una mascara con un centro cuadrado de 1 y el resto en ceros
mask=np.zeros((fils,cols,2), np.uint8)
mask[np.int32(centfils)-10:np.int32(centfils)+10, np.int32(centcols)-10:np.int32(centcols)+10]=1

#aplicar mascaray luego obtenemos la inversa DFT
fshift=dft_shift*mask
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_ishift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_ishift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

displayGray4(img,img_back,fshift_mask_mag,magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()

# %% [markdown]
# **PASA ALTOS**

# %%
img=cv2.imread('figuras.png',0)
img_flotante= np.float32(img)
dft= cv2.dft(img_flotante,flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils,cols=img.shape
centfils,centcols= fils/2, cols/2


#creamos una mascara con un centro cuadrado de 1 y el resto en ceros
mask=np.ones((fils,cols,2), np.uint8)
mask[np.int32(centfils)-5:np.int32(centfils)+5, np.int32(centcols)-5:np.int32(centcols)+5]=0

#aplicar mascaray luego obtenemos la inversa DFT
fshift=dft_shift*mask
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_ishift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_ishift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

displayGray4(img,img_back,fshift_mask_mag,magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()

# %%
img=cv2.imread('figuras.png',0)
img_flotante= np.float32(img)
dft= cv2.dft(img_flotante,flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils,cols=img.shape
centfils,centcols= fils/2, cols/2


#creamos una mascara con un centro cuadrado de 1 y el resto en ceros
mask=np.zeros((fils,cols,2), np.uint8)
mask[np.int32(centfils)-5:np.int32(centfils)+5, np.int32(centcols)-5:np.int32(centcols)+5]=1

#aplicar mascaray luego obtenemos la inversa DFT
fshift=dft_shift*mask
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_ishift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_ishift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

displayGray4(img,img_back,fshift_mask_mag,magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()

# %% [markdown]
# **PASA ALTOS**

# %%
img=cv2.imread('imagen6.png',0)
img_flotante= np.float32(img)
dft= cv2.dft(img_flotante,flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils,cols=img.shape
centfils,centcols= fils/2, cols/2


#creamos una mascara con un centro cuadrado de 1 y el resto en ceros
mask=np.ones((fils,cols,2), np.uint8)
mask[np.int32(centfils)-80:np.int32(centfils)+80, np.int32(centcols)-80:np.int32(centcols)+80]=0

#aplicar mascaray luego obtenemos la inversa DFT
fshift=dft_shift*mask
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_ishift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_ishift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

displayGray4(img,img_back,fshift_mask_mag,magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()
